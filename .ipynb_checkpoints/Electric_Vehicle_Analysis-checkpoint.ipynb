# %%
# import  libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('EV_cars.csv')
data.head()
# Out:
#    Battery                             Car_name  \
# 0     75.0  Tesla Model Y Long Range Dual Motor
# 1     57.5                        Tesla Model 3
# 2     60.5                           BYD ATTO 3
# 3     61.7               MG MG4 Electric 64 kWh
# 4     75.0  Tesla Model 3 Long Range Dual Motor
#
#                                        Car_name_link  Efficiency  Fast_charge  \
# 0  https://ev-database.org/car/1619/Tesla-Model-Y...         172        670.0
# 1     https://ev-database.org/car/1991/Tesla-Model-3         137        700.0
# 2        https://ev-database.org/car/1782/BYD-ATTO-3         183        370.0
# 3  https://ev-database.org/car/1708/MG-MG4-Electr...         171        630.0
# 4  https://ev-database.org/car/1992/Tesla-Model-3...         149        780.0
#
#    Price.DE.  Range  Top_speed  acceleration..0.100.
# 0    59017.0    435        217                   5.0
# 1    46220.0    420        201                   6.1
# 2    44625.0    330        160                   7.3
# 3    39990.0    360        160                   7.9
# 4    55220.0    505        201                   4.4

# %%
data.shape
# Out:
# (360, 9)

# %%
data.describe()
# Out:
#           Battery  Efficiency  Fast_charge      Price.DE.       Range  \
# count  360.000000  360.000000   358.000000     309.000000  360.000000
# mean    71.187500  195.175000   552.960894   67264.284790  369.694444
# std     20.389849   31.909429   236.864801   34508.249544  107.315514
# min     21.300000  137.000000   170.000000   22550.000000  135.000000
# 25%     57.500000  171.000000   360.000000   45690.000000  295.000000
# 50%     71.000000  188.000000   520.000000   56942.000000  380.000000
# 75%     85.000000  208.250000   680.000000   73100.000000  446.250000
# max    123.000000  295.000000  1290.000000  218000.000000  685.000000
#
#         Top_speed  acceleration..0.100.
# count  360.000000            360.000000
# mean   180.919444              7.288889
# std     36.232023              3.005897
# min    125.000000              2.100000
# 25%    155.750000              4.900000
# 50%    180.000000              6.750000
# 75%    200.000000              9.000000
# max    320.000000             19.100000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Battery               360 non-null    float64
#  1   Car_name              360 non-null    object
#  2   Car_name_link         360 non-null    object
#  3   Efficiency            360 non-null    int64
#  4   Fast_charge           358 non-null    float64
#  5   Price.DE.             309 non-null    float64
#  6   Range                 360 non-null    int64
#  7   Top_speed             360 non-null    int64
#  8   acceleration..0.100.  360 non-null    float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 25.4+ KB

# %%
data.columns
# Out:
# Index(['Battery', 'Car_name', 'Car_name_link', 'Efficiency', 'Fast_charge',
#        'Price.DE.', 'Range', 'Top_speed', 'acceleration..0.100.'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Battery                  0
# Car_name                 0
# Car_name_link            0
# Efficiency               0
# Fast_charge              2
# Price.DE.               51
# Range                    0
# Top_speed                0
# acceleration..0.100.     0
# dtype: int64

# %%
data[['Price.DE.']].isnull().sum()
# Out:
# Price.DE.    51
# dtype: int64

# %%
data.tail()
# Out:
#      Battery                         Car_name  \
# 355     46.3  Citroen e-Jumpy Combi XL 50 kWh
# 356     46.3          Fiat E-Ulysse L2 50 kWh
# 357     46.3     Opel Vivaro-e Combi L 50 kWh
# 358     68.0      Opel Zafira-e Life M 75 kWh
# 359     46.3          Fiat E-Ulysse L3 50 kWh
#
#                                          Car_name_link  Efficiency  \
# 355  https://ev-database.org/car/1596/Citroen-e-Jum...         257
# 356  https://ev-database.org/car/1721/Fiat-E-Ulysse...         250
# 357  https://ev-database.org/car/1601/Opel-Vivaro-e...         257
# 358  https://ev-database.org/car/1348/Opel-Zafira-e...         257
# 359  https://ev-database.org/car/1723/Fiat-E-Ulysse...         257
#
#      Fast_charge  Price.DE.  Range  Top_speed  acceleration..0.100.
# 355        290.0    52730.0    180        130                  12.1
# 356        290.0    55990.0    185        130                  12.1
# 357        290.0    51825.0    180        130                  12.1
# 358        290.0    69250.0    265        130                  13.3
# 359        290.0    56990.0    180        130                  12.1

# %%
data.drop('Car_name_link', axis=1, inplace=True)

# %%
data.head()
# Out:
#    Battery                             Car_name  Efficiency  Fast_charge  \
# 0     75.0  Tesla Model Y Long Range Dual Motor         172        670.0
# 1     57.5                        Tesla Model 3         137        700.0
# 2     60.5                           BYD ATTO 3         183        370.0
# 3     61.7               MG MG4 Electric 64 kWh         171        630.0
# 4     75.0  Tesla Model 3 Long Range Dual Motor         149        780.0
#
#    Price.DE.  Range  Top_speed  acceleration..0.100.
# 0    59017.0    435        217                   5.0
# 1    46220.0    420        201                   6.1
# 2    44625.0    330        160                   7.3
# 3    39990.0    360        160                   7.9
# 4    55220.0    505        201                   4.4

# %%
f= data.groupby(['Car_name'])['Price.DE.'].mean().nlargest(20)
f.plot(kind='bar')
# Out:
# <Axes: xlabel='Car_name'>

# %%
f= data.groupby(['Car_name'])['Fast_charge'].mean().nlargest(30)
f.plot(kind='bar')
# Out:
# <Axes: xlabel='Car_name'>

# %%
f= data.groupby(['Car_name'])['Range'].mean().nlargest(10)
f.plot(kind='bar')
# Out:
# <Axes: xlabel='Car_name'>

# %%
data.describe().T
# Out:
#                       count          mean           std      min       25%  \
# Battery               360.0     71.187500     20.389849     21.3     57.50
# Efficiency            360.0    195.175000     31.909429    137.0    171.00
# Fast_charge           358.0    552.960894    236.864801    170.0    360.00
# Price.DE.             309.0  67264.284790  34508.249544  22550.0  45690.00
# Range                 360.0    369.694444    107.315514    135.0    295.00
# Top_speed             360.0    180.919444     36.232023    125.0    155.75
# acceleration..0.100.  360.0      7.288889      3.005897      2.1      4.90
#
#                            50%       75%       max
# Battery                  71.00     85.00     123.0
# Efficiency              188.00    208.25     295.0
# Fast_charge             520.00    680.00    1290.0
# Price.DE.             56942.00  73100.00  218000.0
# Range                   380.00    446.25     685.0
# Top_speed               180.00    200.00     320.0
# acceleration..0.100.      6.75      9.00      19.1

# %%
data.groupby(['Car_name']).value_counts().head()
# Out:
# Car_name                     Battery  Efficiency  Fast_charge  Price.DE.  Range  Top_speed  acceleration..0.100.
# Abarth 500e Convertible      37.8     168         370.0        40990.0    225    155        7.0                     1
# Abarth 500e Hatchback        37.8     168         370.0        37990.0    225    155        7.0                     1
# Aiways U5                    60.0     190         380.0        39563.0    315    150        7.5                     1
# Aiways U6                    60.0     171         430.0        47588.0    350    160        7.0                     1
# Audi Q4 Sportback e-tron 45  77.0     177         650.0        54950.0    435    180        6.7                     1
# dtype: int64

# %%
data['Car_name'].value_counts()[:5]
# Out:
# Mercedes EQB 300 4MATIC        2
# Mini Cooper SE                 2
# Mercedes EQE SUV 500 4MATIC    2
# Mercedes EQA 300 4MATIC        2
# Mercedes EQA 250+              2
# Name: Car_name, dtype: int64

# %%
data.duplicated('Car_name')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 355    False
# 356    False
# 357    False
# 358    False
# 359    False
# Length: 360, dtype: bool

# %%
data.drop_duplicates(subset='Car_name', inplace=True)

# %%
data.shape
# Out:
# (351, 8)

# %%
data.head()
# Out:
#    Battery                             Car_name  Efficiency  Fast_charge  \
# 0     75.0  Tesla Model Y Long Range Dual Motor         172        670.0
# 1     57.5                        Tesla Model 3         137        700.0
# 2     60.5                           BYD ATTO 3         183        370.0
# 3     61.7               MG MG4 Electric 64 kWh         171        630.0
# 4     75.0  Tesla Model 3 Long Range Dual Motor         149        780.0
#
#    Price.DE.  Range  Top_speed  acceleration..0.100.
# 0    59017.0    435        217                   5.0
# 1    46220.0    420        201                   6.1
# 2    44625.0    330        160                   7.3
# 3    39990.0    360        160                   7.9
# 4    55220.0    505        201                   4.4

# %%
data.groupby(['Car_name'])['Efficiency'].sum().nlargest().head()
# Out:
# Car_name
# Mercedes eVito Tourer Extra-Long 90 kWh    295
# Mercedes eVito Tourer Extra-Long 60 kWh    293
# Mercedes EQV 300 Extra-Long                290
# Mercedes EQV 300 Long                      290
# Mercedes eVito Tourer Long 90 kWh          290
# Name: Efficiency, dtype: int64

# %%
efficiency_1 = data.groupby(['Car_name'])['Efficiency'].sum().nlargest().head()
efficiency_1.plot(kind='pie',autopct="%0.1f%%").set_title('Top Ten Car Company Contribution in the market')
# Out:
# Text(0.5, 1.0, 'Top Ten Car Company Contribution in the market')

# %%
data.columns
# Out:
# Index(['Battery', 'Car_name', 'Efficiency', 'Fast_charge', 'Price.DE.',
#        'Range', 'Top_speed', 'acceleration..0.100.'],
#       dtype='object')

# %%
sns.histplot(data['Range'])
# Out:
# <Axes: xlabel='Range', ylabel='Count'>

# %%
sns.histplot(data['Top_speed'])
# Out:
# <Axes: xlabel='Top_speed', ylabel='Count'>

# %%
sns.histplot(data['Price.DE.'])
# Out:
# <Axes: xlabel='Price.DE.', ylabel='Count'>

# %%
data['Battery'].nunique()
# Out:
# 98

# %%
sns.scatterplot(data=data,x='Battery',y='Price.DE.',hue='Battery')
# Out:
# <Axes: xlabel='Battery', ylabel='Price.DE.'>

# %%
y = data.groupby(['Car_name'])['Battery'].mean()
plt.plot(y)

# %%
import seaborn as sns 
sns.heatmap(data.corr(), cmap='coolwarm', annot=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3924\751625291.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), cmap='coolwarm', annot=True)
# <Axes: >

# %%
data.corr(method='pearson', numeric_only=True)
# Out:
#                        Battery  Efficiency  Fast_charge  Price.DE.     Range  \
# Battery               1.000000    0.171179     0.600999   0.702632  0.882668
# Efficiency            0.171179    1.000000    -0.281838   0.172951 -0.286626
# Fast_charge           0.600999   -0.281838     1.000000   0.622903  0.722454
# Price.DE.             0.702632    0.172951     0.622903   1.000000  0.594242
# Range                 0.882668   -0.286626     0.722454   0.594242  1.000000
# Top_speed             0.700865   -0.181096     0.776974   0.765731  0.747050
# acceleration..0.100. -0.612778    0.393398    -0.673943  -0.540267 -0.747072
#
#                       Top_speed  acceleration..0.100.
# Battery                0.700865             -0.612778
# Efficiency            -0.181096              0.393398
# Fast_charge            0.776974             -0.673943
# Price.DE.              0.765731             -0.540267
# Range                  0.747050             -0.747072
# Top_speed              1.000000             -0.843191
# acceleration..0.100.  -0.843191              1.000000
